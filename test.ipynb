# %%
name="Adithya"
age=19
height=5.8
is_student=True

print("name = ",name)
print("age = ",age)
print("height = ",height)
print("is student = ",is_student)
age=input("what is the age?")
print(age)
type(name)
# Out:
# name =  Adithya
# age =  19
# height =  5.8
# is student =  True
# 90
# str

# %%
a=10
b=5
addresult=a+b
print(addresult)
subresult=a-b
print(subresult)
mulresult=a*b
print(mulresult)
divresult=int(a/b)
print(divresult)
type(divresult)
# Out:
# 15
# 5
# 50
# 2
# int

# %%
print(a>b)
print(b==a)
print(b>=a)
# Out:
# True
# False
# False

# %%
x=True
y=True
result=x and y
print(result)

x=False
y=True
result1=x and y
print(result1)

x=False
y=True
result2=x or y
print(result2)

x=False
y=True
result3=not(x or y)
print(result3)
# Out:
# True
# False
# True
# False
