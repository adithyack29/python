# %%
name="Adithya"
age=19
height=5.8
is_student=True

print("name = ",name)
print("age = ",name)
print("height = ",height)
print("is student = ",is_student)
# Out:
# name =  Adithya
# age =  Adithya
# height =  5.8
# is student =  True
